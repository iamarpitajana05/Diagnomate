# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Brain Tumor.csv")

# %%
data.head()
# Out:
#   Patient ID  Age  Gender Tumor Type  Tumor Size (cm) Tumor Location  \
# 0     P00001   69  Female     Benign             5.01        Frontal
# 1     P00002   32  Female  Malignant             3.52       Temporal
# 2     P00003   78  Female     Benign             8.24       Temporal
# 3     P00004   38    Male     Benign             9.58       Parietal
# 4     P00005   41    Male  Malignant             1.40       Parietal
#
#   MRI Findings  WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test COVID Severity  \
# 0      Present                  4.32           32.53  Positive           Mild
# 1      Present                  5.86           39.84  Negative       Moderate
# 2        Clear                  8.86           34.18  Negative            NaN
# 3        Clear                  6.77           16.38  Positive         Severe
# 4        Clear                  4.90           18.76  Positive           Mild
#
#    Oxygen Sat (%) Symptoms (Headache) Symptoms (Seizures) Treatment Type  \
# 0           96.67                  No                  No       Steroids
# 1           85.72                 Yes                 Yes    Observation
# 2           89.67                 Yes                 Yes       Steroids
# 3           89.30                 Yes                 Yes   Radiotherapy
# 4           92.98                  No                  No       Steroids
#
#          Outcome
# 0       Deceased
# 1  Complications
# 2      Recovered
# 3  Complications
# 4      Recovered

# %%
data.tail()
# Out:
#       Patient ID  Age  Gender Tumor Type  Tumor Size (cm) Tumor Location  \
# 49995     P49996   65    Male  Malignant             5.37      Occipital
# 49996     P49997   72    Male     Benign             9.64       Parietal
# 49997     P49998   80  Female     Benign             7.68       Parietal
# 49998     P49999   23    Male     Benign             4.17        Frontal
# 49999     P50000   52    Male  Malignant             7.01        Frontal
#
#       MRI Findings  WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test  \
# 49995      Present                 13.91           44.58  Negative
# 49996      Present                 13.62           20.15  Negative
# 49997        Clear                  9.71           46.38  Negative
# 49998      Present                 12.10           16.47  Positive
# 49999      Present                 12.03           22.59  Negative
#
#       COVID Severity  Oxygen Sat (%) Symptoms (Headache) Symptoms (Seizures)  \
# 49995           Mild           87.53                  No                  No
# 49996       Moderate           91.35                 Yes                  No
# 49997           Mild           96.95                 Yes                 Yes
# 49998           Mild           86.84                  No                  No
# 49999       Moderate           94.38                 Yes                  No
#
#       Treatment Type        Outcome
# 49995       Steroids  Complications
# 49996    Observation  Complications
# 49997       Steroids       Deceased
# 49998   Radiotherapy       Deceased
# 49999    Observation       Deceased

# %%
data.shape
# Out:
# (50000, 16)

# %%
# Drop unnecessary columns

brain = data.drop(columns=['Patient ID'])

# %%
brain
# Out:
#        Age  Gender Tumor Type  Tumor Size (cm) Tumor Location MRI Findings  \
# 0       69  Female     Benign             5.01        Frontal      Present
# 1       32  Female  Malignant             3.52       Temporal      Present
# 2       78  Female     Benign             8.24       Temporal        Clear
# 3       38    Male     Benign             9.58       Parietal        Clear
# 4       41    Male  Malignant             1.40       Parietal        Clear
# ...    ...     ...        ...              ...            ...          ...
# 49995   65    Male  Malignant             5.37      Occipital      Present
# 49996   72    Male     Benign             9.64       Parietal      Present
# 49997   80  Female     Benign             7.68       Parietal        Clear
# 49998   23    Male     Benign             4.17        Frontal      Present
# 49999   52    Male  Malignant             7.01        Frontal      Present
#
#        WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test COVID Severity  \
# 0                      4.32           32.53  Positive           Mild
# 1                      5.86           39.84  Negative       Moderate
# 2                      8.86           34.18  Negative            NaN
# 3                      6.77           16.38  Positive         Severe
# 4                      4.90           18.76  Positive           Mild
# ...                     ...             ...       ...            ...
# 49995                 13.91           44.58  Negative           Mild
# 49996                 13.62           20.15  Negative       Moderate
# 49997                  9.71           46.38  Negative           Mild
# 49998                 12.10           16.47  Positive           Mild
# 49999                 12.03           22.59  Negative       Moderate
#
#        Oxygen Sat (%) Symptoms (Headache) Symptoms (Seizures) Treatment Type  \
# 0               96.67                  No                  No       Steroids
# 1               85.72                 Yes                 Yes    Observation
# 2               89.67                 Yes                 Yes       Steroids
# 3               89.30                 Yes                 Yes   Radiotherapy
# 4               92.98                  No                  No       Steroids
# ...               ...                 ...                 ...            ...
# 49995           87.53                  No                  No       Steroids
# 49996           91.35                 Yes                  No    Observation
# 49997           96.95                 Yes                 Yes       Steroids
# 49998           86.84                  No                  No   Radiotherapy
# 49999           94.38                 Yes                  No    Observation
#
#              Outcome
# 0           Deceased
# 1      Complications
# 2          Recovered
# 3      Complications
# 4          Recovered
# ...              ...
# 49995  Complications
# 49996  Complications
# 49997       Deceased
# 49998       Deceased
# 49999       Deceased
#
# [50000 rows x 15 columns]

# %%
brain.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Tumor Type                  0
# Tumor Size (cm)             0
# Tumor Location              0
# MRI Findings                0
# WBC Count (x10^3/uL)        0
# Lymphocyte (%)              0
# PCR Test                    0
# COVID Severity          12585
# Oxygen Sat (%)              0
# Symptoms (Headache)         0
# Symptoms (Seizures)         0
# Treatment Type              0
# Outcome                     0
# dtype: int64

# %%
# Handle missing values by filling with the mode (most common value)
brain['COVID Severity'].fillna(brain['COVID Severity'].mode()[0], inplace=True)
# Out:
# <ipython-input-15-958293309dde>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   brain['COVID Severity'].fillna(brain['COVID Severity'].mode()[0], inplace=True)

# %%
brain.isna().sum()
# Out:
# Age                     0
# Gender                  0
# Tumor Type              0
# Tumor Size (cm)         0
# Tumor Location          0
# MRI Findings            0
# WBC Count (x10^3/uL)    0
# Lymphocyte (%)          0
# PCR Test                0
# COVID Severity          0
# Oxygen Sat (%)          0
# Symptoms (Headache)     0
# Symptoms (Seizures)     0
# Treatment Type          0
# Outcome                 0
# dtype: int64

# %%
brain.describe()
# Out:
#                 Age  Tumor Size (cm)  WBC Count (x10^3/uL)  Lymphocyte (%)  \
# count  50000.000000     50000.000000          50000.000000    50000.000000
# mean      50.937700         5.239460              9.500999       30.021588
# std       19.373208         2.741997              3.179633       11.572717
# min       18.000000         0.500000              4.000000       10.000000
# 25%       34.000000         2.860000              6.740000       19.940000
# 50%       51.000000         5.230000              9.510000       30.070000
# 75%       68.000000         7.590000             12.250000       40.040000
# max       84.000000        10.000000             15.000000       50.000000
#
#        Oxygen Sat (%)
# count    50000.000000
# mean        87.464613
# std          7.216338
# min         75.000000
# 25%         81.190000
# 50%         87.460000
# 75%         93.710000
# max        100.000000

# %%
brain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   50000 non-null  int64
#  1   Gender                50000 non-null  object
#  2   Tumor Type            50000 non-null  object
#  3   Tumor Size (cm)       50000 non-null  float64
#  4   Tumor Location        50000 non-null  object
#  5   MRI Findings          50000 non-null  object
#  6   WBC Count (x10^3/uL)  50000 non-null  float64
#  7   Lymphocyte (%)        50000 non-null  float64
#  8   PCR Test              50000 non-null  object
#  9   COVID Severity        50000 non-null  object
#  10  Oxygen Sat (%)        50000 non-null  float64
#  11  Symptoms (Headache)   50000 non-null  object
#  12  Symptoms (Seizures)   50000 non-null  object
#  13  Treatment Type        50000 non-null  object
#  14  Outcome               50000 non-null  object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 5.7+ MB

# %%
# Encode categorical variables
categorical_columns = brain.select_dtypes(include='object').columns
label_encoders = {}

# %%
label_encoders = {}
for column in categorical_columns:
    label_encoder = LabelEncoder()
    brain[column] = label_encoder.fit_transform(brain[column])
    label_encoders[column] = label_encoder

# %%
brain.head()
# Out:
#    Age  Gender  Tumor Type  Tumor Size (cm)  Tumor Location  MRI Findings  \
# 0   69       0           0             5.01               0             1
# 1   32       0           1             3.52               3             1
# 2   78       0           0             8.24               3             0
# 3   38       1           0             9.58               2             0
# 4   41       1           1             1.40               2             0
#
#    WBC Count (x10^3/uL)  Lymphocyte (%)  PCR Test  COVID Severity  \
# 0                  4.32           32.53         1               0
# 1                  5.86           39.84         0               1
# 2                  8.86           34.18         0               2
# 3                  6.77           16.38         1               2
# 4                  4.90           18.76         1               0
#
#    Oxygen Sat (%)  Symptoms (Headache)  Symptoms (Seizures)  Treatment Type  \
# 0           96.67                    0                    0               3
# 1           85.72                    1                    1               1
# 2           89.67                    1                    1               3
# 3           89.30                    1                    1               2
# 4           92.98                    0                    0               3
#
#    Outcome
# 0        1
# 1        0
# 2        2
# 3        0
# 4        2

# %%
brain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   50000 non-null  int64
#  1   Gender                50000 non-null  int64
#  2   Tumor Type            50000 non-null  int64
#  3   Tumor Size (cm)       50000 non-null  float64
#  4   Tumor Location        50000 non-null  int64
#  5   MRI Findings          50000 non-null  int64
#  6   WBC Count (x10^3/uL)  50000 non-null  float64
#  7   Lymphocyte (%)        50000 non-null  float64
#  8   PCR Test              50000 non-null  int64
#  9   COVID Severity        50000 non-null  int64
#  10  Oxygen Sat (%)        50000 non-null  float64
#  11  Symptoms (Headache)   50000 non-null  int64
#  12  Symptoms (Seizures)   50000 non-null  int64
#  13  Treatment Type        50000 non-null  int64
#  14  Outcome               50000 non-null  int64
# dtypes: float64(4), int64(11)
# memory usage: 5.7 MB

# %%
# Split data into features and target
X = brain.drop(columns=['Outcome'])
y = brain['Outcome']

# %%
# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Build and train the Random Forest Classifier
model = RandomForestClassifier(random_state=42, n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions and evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("-----------------------")
print(f"Accuracy: {accuracy}")
print("-----------------------")
print("Classification Report:")
print(report)
# Out:
# -----------------------
# Accuracy: 0.331
# -----------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.34      0.34      0.34      3424
#            1       0.33      0.35      0.34      3350
#            2       0.32      0.31      0.31      3226
#
#     accuracy                           0.33     10000
#    macro avg       0.33      0.33      0.33     10000
# weighted avg       0.33      0.33      0.33     10000

# %%
# Evaluate the model
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.3375

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.332

# %%
# Example prediction
input_data = (78,0,0,8.24,3,0,8.86,34.18,0,2,89.67,1,1,3)  # Update with real values

# Changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Using the trained classifier directly for prediction
prediction = classifier.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print('The person does not have a brain tumor')
else:
    print('The person has a brain tumor')
# Out:
# [0]
# The person does not have a brain tumor
